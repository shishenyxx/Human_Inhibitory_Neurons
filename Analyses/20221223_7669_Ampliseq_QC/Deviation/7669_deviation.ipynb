# %%
library(ggplot2)
library(dplyr)
library(gplots)
library(reshape2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘gplots’
#
#
# The following object is masked from ‘package:stats’:
#
#     lowess

# %%
filtered <- read.table("../20230101_QC/final_summary_anno3.txt",header=T,sep="\t")
variant_list <- read.table("../variant_annotation/780_variant_annotation_COUPTF2_TBR1_DLX1_CBH.csv",header=T,sep=",",row.names=1)

# %%
mosaic_filtered <- filtered[filtered$Mosaic_shared_btw_WGS_Amp==1,]
shared_variant_list<-variant_list[variant_list$sample_number_presented>1,]
shared_mosaic_filtered<-mosaic_filtered[mosaic_filtered$CHROM.POS.REF.ALT %in% rownames(shared_variant_list),]

# %%
melt_mtcars<-shared_mosaic_filtered[,c("ID", "MAF", "CHROM.POS.REF.ALT","Cell_Type","Organ",'Region','Punch','Hemisphere')]
melt_mtcars$MAF <- sqrt(melt_mtcars$MAF)
casted_MAF_VarBySample <- dcast(melt_mtcars, CHROM.POS.REF.ALT~ID, value.var = "MAF" , na.rm=T)
rownames(casted_MAF_VarBySample) <- casted_MAF_VarBySample$CHROM.POS.REF.ALT
casted_MAF_VarBySample2 <- casted_MAF_VarBySample[ , !(names(casted_MAF_VarBySample) %in% c("CHROM.POS.REF.ALT"))]

# %%
data <- data.frame()
for(x in 1:nrow(casted_MAF_VarBySample2)){
    data['7669_L_F_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_F_1_DLX1'
    data['7669_L_P_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_P_1_DLX1'
    data['7669_L_I_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_I_1_DLX1'
    data['7669_L_O_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_O_1_DLX1'
    data['7669_L_T_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_T_1_DLX1'
    #data['7669_L_mO_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_mO_DLX1'
    data['7669_R_EC_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_EC_DLX1'
    #data['7669_L_CC_2_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_CC_2_DLX1'
    data['7669_R_F_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_F_1_DLX1'
    data['7669_R_P_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_P_1_DLX1'
    data['7669_R_I_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_I_1_DLX1'
    data['7669_R_O_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_O_1_DLX1'
    data['7669_R_T_1_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_T_1_DLX1'
    data['7669_R_mO_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_mO_DLX1'
    #data['7669_L_EC_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_EC_DLX1'
    #data['7669_R_CCMid_DLX1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_CCMid_DLX1'
}

# %%
data2 <- data.frame()
for(x in 1:nrow(casted_MAF_VarBySample2)){
    data2['7669_L_F_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_F_1_TBR1'
    data2['7669_L_P_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_P_1_TBR1'
    data2['7669_L_I_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_I_1_TBR1'
    data2['7669_L_O_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_O_1_TBR1'
    data2['7669_L_T_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_L_T_1_TBR1'
    data2['7669_R_EC_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_EC_TBR1'
    data2['7669_R_F_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_F_1_TBR1'
    data2['7669_R_P_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_P_1_TBR1'
    data2['7669_R_I_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_I_1_TBR1'
    data2['7669_R_O_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_O_1_TBR1'
    data2['7669_R_T_1_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_T_1_TBR1'
    data2['7669_R_mO_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_mO_TBR1'
}

# %%
data3 <- data.frame()
for(x in 1:nrow(casted_MAF_VarBySample2)){
    data3['7669_R_CC_Mid_TBR1',x]<-casted_MAF_VarBySample2[x,]$'7669_R_CC_Mid_TBR1'
    data3['7669_L_F_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_L_F_1_COUPTF2'
    data3['7669_L_P_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_L_P_1_COUPTF2'
    data3['7669_L_I_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_L_I_1_COUPTF2'
    data3['7669_L_O_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_L_O_1_COUPTF2'
    data3['7669_L_T_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_L_T_1_COUPTF2'
    #data3['7669_L_mO_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_L_mO_COUPTF2'
    data3['7669_R_EC_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_R_EC_COUPTF2'
    #data3['7669_L_CC_2_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_L_CC_2_COUPTF2'
    data3['7669_R_F_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_R_F_1_COUPTF2'
    data3['7669_R_P_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_R_P_1_COUPTF2'
    data3['7669_R_I_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_R_I_1_COUPTF2'
    data3['7669_R_O_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_R_O_1_COUPTF2'
    data3['7669_R_T_1_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_R_T_1_COUPTF2'
    data3['7669_R_mO_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_R_mO_COUPTF2'
    #data3['7669_L_EC_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_L_EC_COUPTF2'
    #data3['7669_R_CCMid_COUPTF2',x]<-casted_MAF_VarBySample2[x,]$'7669_R_CCMid_COUPTF2'
}

# %%
data[,'sample']<-rownames(data)
data2[,'sample']<-rownames(data2)
data3[,'sample']<-rownames(data3)

# %%
data[,'sample']<-as.character(data[,'sample'])
data2[,'sample']<-as.character(data2[,'sample'])
data3[,'sample']<-as.character(data3[,'sample'])

# %%
result <- apply(data, 2, sd)
result<-data.frame(na.omit(result))
result2 <- apply(data2, 2, sd)
result2<-data.frame(na.omit(result2))
result3 <- apply(data3, 2, sd)
result3 <-data.frame(na.omit(result3))
# Out:
# Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# “NAs introduced by coercion”
# Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# “NAs introduced by coercion”
# Warning message in var(if (is.vector(x) || is.factor(x)) x else as.double(x), na.rm = na.rm):
# “NAs introduced by coercion”

# %%
results<-cbind(result,result2,result3)
colnames(results)<-c("DLX1","TBR1","COUPTF2")

# %%
p <- ggplot(melt(results), aes(x=variable, y=value, color=variable)) + 
  geom_violin(binaxis='', stackdir='', dotsize=1) + scale_color_manual(values=c("#EF6666","#7CBD42","#61BDEA")) +
#geom_dotplot(binaxis='y', stackdir='center', dotsize=0.1)+
geom_jitter(shape=16, position=position_jitter(0.2)) + theme_classic()
# Out:
# No id variables; using all as measure variables
#
# Warning message in geom_violin(binaxis = "", stackdir = "", dotsize = 1):
# “Ignoring unknown parameters: `binaxis`, `stackdir`, and `dotsize`”

# %%
p
# Out:
# plot without title

# %%
TukeyHSD(aov(value ~ variable, data = melt(results)))
# Out:
# No id variables; using all as measure variables
#
# No id variables; using all as measure variables
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = value ~ variable, data = melt(results))
#
# $variable
#                       diff          lwr          upr     p adj
# TBR1-DLX1    -0.0008017792 -0.005582801  0.003979243 0.9179728
# COUPTF2-DLX1 -0.0067465898 -0.011527612 -0.001965568 0.0027919
# COUPTF2-TBR1 -0.0059448106 -0.010725833 -0.001163788 0.0101072

# %%
pdf(file="7669_variant_AF_deviation.pdf",width=10,height=10)
p
dev.off()
# Out:
# png
#   2
