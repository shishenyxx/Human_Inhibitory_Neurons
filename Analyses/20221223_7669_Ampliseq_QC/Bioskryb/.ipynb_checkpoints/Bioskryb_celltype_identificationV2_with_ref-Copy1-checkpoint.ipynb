# %%
library(dplyr)
library(Seurat)
#library(umap)
#library(FactoMineR)
suppressPackageStartupMessages(library(Seurat))
suppressPackageStartupMessages(library(ggplot2))
suppressPackageStartupMessages(library(dplyr))
suppressPackageStartupMessages(library(patchwork))
#suppressPackageStartupMessages(library(refGenome))
suppressPackageStartupMessages(library(data.table))
suppressPackageStartupMessages(library(future))
suppressPackageStartupMessages(library(ggrepel))
#suppressPackageStartupMessages(library(WGCNA))
suppressPackageStartupMessages(library(lsa))
suppressPackageStartupMessages(library(ComplexHeatmap))
suppressPackageStartupMessages(library(circlize))
suppressPackageStartupMessages(library(stringr))
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# The legacy packages maptools, rgdal, and rgeos, underpinning this package
# will retire shortly. Please refer to R-spatial evolution reports on
# https://r-spatial.org/r/2023/05/15/evolution4.html for details.
# This package is now running under evolution status 0
#
# rgeos version: 0.6-3, (SVN revision 696)
#  GEOS runtime version: 3.11.2-CAPI-1.17.2
#  Please note that rgeos will be retired during October 2023,
# plan transition to sf or terra functions using GEOS at your earliest convenience.
# See https://r-spatial.org/r/2023/05/15/evolution4.html for details.
#  GEOS using OverlayNG
#  Linking to sp version: 1.6-1
#  Polygon checking: TRUE
#
#
# Attaching SeuratObject

# %% [markdown]
# # Cell type annotation

# %%
# df6<-readRDS("/projects/ps-gleesonlab7/User/chchung/4_interneuron/2022-09-09_10XGE_pilot/Ctrl8553.rds")
# df7<-readRDS("/projects/ps-gleesonlab7/User/chchung/4_interneuron/2022-09-09_10XGE_pilot/Ctrl8718.rds")
# df8 <- readRDS("/projects/ps-gleesonlab7/User/chchung/3_FCD_project1/2021-10-26_FCD_snRNAseq/2021-10-29_20211026_FCD_snRNAseq_CTRL83538352_demuxlet_4556nu.rds")
# df8<-readRDS("/projects/ps-gleesonlab8/Uniformly_processed_data/20230609_Changuk_Interneuron_10XGE_IGM/TBR1.rds")
# countsData1<-read.delim(file = "/projects/ps-gleesonlab8/User/chchung/DRG/20230616_bioskryb_interneuron_plate1_Changuk.csv", header = TRUE, sep = ",",row.names = 1)
# countsData2<-read.delim(file = "/projects/ps-gleesonlab8/User/chchung/DRG/20230616_bioskryb_interneuron_plate2_Changuk.csv", header = TRUE, sep = ",",row.names = 1)
# countsData3<-read.delim(file = "/projects/ps-gleesonlab8/rawUser/chchung/DRG/20230616_bioskryb_interneuron_plate3_Changuk.csv", header = TRUE, sep = ",",row.names = 1)
countsData4<-read.delim(file = "/projects/ps-gleesonlab8/User/chchung/DRG/20230708_bioskryb_interneuron_plate1_1_Changuk_rawcount.csv", header = TRUE, sep = ",",row.names = 1)
countsData5<-read.delim(file = "/projects/ps-gleesonlab8/User/chchung/DRG/20230708_bioskryb_interneuron_plate1_2_23_Changuk_rowcount.csv", header = TRUE, sep = ",",row.names = 1)
countsData6<-read.delim(file = "/projects/ps-gleesonlab8/User/chchung/Interneuron/20221223_7669_Ampliseq_QC/Bioskryb/SMARTseq/trimmed_means.csv", header = TRUE, sep = ",",row.names = 1)

# %%
head(countsData6)
# Out:
#         Exc.L5.6.FEZF2.ANKRD20A1 Exc.L5.6.THEMIS.TMEM233 Inh.L1.LAMP5.NDNF
# 3.8-1.2 0.0000000                0.0000000               0.0000000000
# 3.8-1.3 0.0000000                0.0000000               0.0000000000
# 3.8-1.4 0.0000000                0.0000000               0.0000000000
# 3.8-1.5 0.0000000                0.0000000               0.0000000000
# 5-HT3C2 0.0000000                0.0000000               0.0000000000
# A1BG    0.3356098                0.7959542               0.0009090909
#         Exc.L6.FEZF2.CPZ Astro.L1.FGFR3.MT1G Exc.L2.3.LINC00507.RPL9P17
# 3.8-1.2 0.0000000        0                   0.0000000
# 3.8-1.3 0.0000000        0                   0.0000000
# 3.8-1.4 0.0000000        0                   0.0000000
# 3.8-1.5 0.0000000        0                   0.0000000
# 5-HT3C2 0.0000000        0                   0.0000000
# A1BG    0.4040158        0                   0.3238947
#         Exc.L6.FEZF2.KRT17 Exc.L3.4.RORB.FOLH1B Endo.L2.5.CLDN5
# 3.8-1.2 0.0000000          0.000000             0
# 3.8-1.3 0.0000000          0.000000             0
# 3.8-1.4 0.0000000          0.000000             0
# 3.8-1.5 0.0000000          0.000000             0
# 5-HT3C2 0.0000000          0.000000             0
# A1BG    0.7611154          0.255572             0
#         Exc.L5.6.RORB.LINC00320 ⋯ Exc.L4.RORB.CACNG5 Exc.L6.FEZF2.FAM95C
# 3.8-1.2 0.0000000               ⋯ 0                  0.0000000
# 3.8-1.3 0.0000000               ⋯ 0                  0.0000000
# 3.8-1.4 0.0000000               ⋯ 0                  0.0000000
# 3.8-1.5 0.0000000               ⋯ 0                  0.0000000
# 5-HT3C2 0.0000000               ⋯ 0                  0.0000000
# A1BG    0.3470149               ⋯ 0                  0.4151348
#         Inh.L1.3.VIP.GGH Exc.L3.5.FEZF2.DCN Exc.L6.FEZF2.ETV4
# 3.8-1.2 0                0.00000000         0.000000
# 3.8-1.3 0                0.00000000         0.000000
# 3.8-1.4 0                0.00000000         0.000000
# 3.8-1.5 0                0.00000000         0.000000
# 5-HT3C2 0                0.00000000         0.000000
# A1BG    0                0.09619047         0.209433
#         Exc.L5.6.FEZF2.RSAD2 Inh.L1.ADARB2.DISP2 Inh.L5.6.LAMP5.SFTA3
# 3.8-1.2 0                    0                   0.00000000
# 3.8-1.3 0                    0                   0.00000000
# 3.8-1.4 0                    0                   0.00000000
# 3.8-1.5 0                    0                   0.00000000
# 5-HT3C2 0                    0                   0.00000000
# A1BG    0                    0                   0.01094637
#         Exc.L6.FEZF2.TBC1D26 Inh.L4.5.PVALB.TRIM67
# 3.8-1.2 0.000000             0
# 3.8-1.3 0.000000             0
# 3.8-1.4 0.000000             0
# 3.8-1.5 0.000000             0
# 5-HT3C2 0.000000             0
# A1BG    1.092742             0

# %%
# rownames(countsData1)<-countsData1$SYMBOL
# countsData1<-countsData1[,!colnames(countsData1) %in% (c("Chr","Start","End","Strand","Length","SYMBOL"))]
# rownames(countsData2)<-countsData2$SYMBOL
# countsData2<-countsData2[,!colnames(countsData2) %in% (c("Chr","Start","End","Strand","Length","SYMBOL"))]
# rownames(countsData3)<-countsData3$SYMBOL
# countsData3<-countsData3[,!colnames(countsData3) %in% (c("Chr","Start","End","Strand","Length","SYMBOL"))]
rownames(countsData4)<-countsData4$SYMBOL
countsData4<-countsData4[,!colnames(countsData4) %in% (c("Chr","Start","End","Strand","Length","SYMBOL"))]
rownames(countsData5)<-countsData5$SYMBOL
countsData5<-countsData5[,!colnames(countsData5) %in% (c("Chr","Start","End","Strand","Length","SYMBOL"))]

# %%
# df1 <- CreateSeuratObject(counts =(countsData1), project = "bioskryb_7669_old_F")
# df2 <- CreateSeuratObject(counts =(countsData2), project = "bioskryb_7669_old_T")
# df3 <- CreateSeuratObject(counts =(countsData3), project = "bioskryb_7669_old_HIP")
df4 <- CreateSeuratObject(counts =(countsData4), project = "bioskryb_7669_F1")
df5 <- CreateSeuratObject(counts =(countsData5), project = "bioskryb_7669_F2TH")
df6 <- CreateSeuratObject(counts =(countsData6), project = "ref")

# %%
df0 <- merge(df4, y = c(df5,df6), 
             add.cell.ids = c("bioskryb_7669_F1","bioskryb_7669_F2TH","ref"))

# %%
merge<-df0

# %%
df0<-merge

# %%
unique(merge@meta.data$orig.ident)
# Out:
# [1] "X.projects.ps.gleesonlab8.User.arzoo.20230706"
# [2] "X.projects.ps.gleesonlab8.User.arzoo.20230727"
# [3] "ref"

# %%
df0@meta.data[df0@meta.data$orig.ident=="X.projects.ps.gleesonlab8.User.arzoo.20230706",]$orig.ident<-"bioskryb_7669_F1"
df0@meta.data[df0@meta.data$orig.ident=="X.projects.ps.gleesonlab8.User.arzoo.20230727",]$orig.ident<-"bioskryb_7669_F2TH"
df0@meta.data[df0@meta.data$orig.ident=="ref",]$orig.ident<-"ref"

# %%
my_string <- rownames(df0@meta.data)
extracted <- str_extract(my_string, "SC\\d{2}")
print(extracted)
df0@meta.data$Cell_ID<-c(extracted)

my_string <- rownames(df0@meta.data[df0@meta.data$orig.ident=="bioskryb_7669_F1",])
my_string2 <- rownames(df0@meta.data[df0@meta.data$orig.ident=="bioskryb_7669_F2TH",])
my_string3 <- rownames(df0@meta.data[df0@meta.data$orig.ident=="ref",])

extracted <- str_extract(my_string, "PL01\\..*?(?=\\.)")
extracted2 <- str_extract(my_string2, "PL0._.*?(?=_)")
# Out:
#   [1] "SC01" "SC02" "SC03" "SC04" "SC05" "SC07" "SC08" "SC09" "SC10" "SC11"
#  [11] "SC12" "SC13" "SC14" "SC15" "SC16" "SC17" "SC18" "SC19" "SC20" "SC21"
#  [21] "SC22" "SC23" "SC24" "SC25" "SC26" "SC27" "SC28" "SC29" "SC30" "SC31"
#  [31] "SC32" "SC33" "SC34" "SC35" "SC36" "SC37" "SC38" "SC39" "SC40" "SC41"
#  [41] "SC42" "SC43" "SC44" "SC45" "SC46" "SC47" "SC48" "SC49" "SC50" "SC51"
#  [51] "SC53" "SC54" "SC55" "SC56" "SC57" "SC58" "SC59" "SC60" "SC61" "SC62"
#  [61] "SC65" "SC67" "SC68" "SC69" "SC70" "SC71" "SC72" "SC73" "SC74" "SC75"
#  [71] "SC76" "SC77" "SC78" "SC79" "SC82" "SC86" "SC87" "SC89" "SC90" "SC91"
#  [81] "SC92" "SC93" "SC94" "SC96" "SC01" "SC02" "SC03" "SC04" "SC05" "SC06"
#  [91] "SC07" "SC08" "SC09" "SC10" "SC11" "SC12" "SC13" "SC14" "SC15" "SC16"
# [101] "SC17" "SC18" "SC19" "SC20" "SC21" "SC22" "SC23" "SC24" "SC25" "SC26"
# [111] "SC27" "SC28" "SC29" "SC30" "SC31" "SC32" "SC33" "SC34" "SC35" "SC36"
# [121] "SC37" "SC38" "SC39" "SC40" "SC41" "SC42" "SC43" "SC44" "SC45" "SC46"
# [131] "SC47" "SC48" "SC49" "SC50" "SC51" "SC52" "SC53" "SC54" "SC55" "SC56"
# [141] "SC57" "SC58" "SC59" "SC60" "SC61" "SC62" "SC63" "SC64" "SC65" "SC66"
# [151] "SC67" "SC68" "SC69" "SC70" "SC71" "SC72" "SC73" "SC74" "SC75" "SC76"
# [161] "SC77" "SC78" "SC79" "SC80" "SC81" "SC82" "SC83" "SC84" "SC85" "SC86"
# [171] "SC87" "SC88" "SC89" "SC90" "SC91" "SC92" "SC93" "SC94" "SC96" "SC03"
# [181] "SC04" "SC05" "SC06" "SC07" "SC08" "SC09" "SC10" "SC11" "SC12" "SC13"
# [191] "SC14" "SC15" "SC16" "SC17" "SC18" "SC19" "SC20" "SC21" "SC22" "SC23"
# [201] "SC24" "SC25" "SC26" "SC27" "SC28" "SC29" "SC30" "SC31" "SC32" "SC33"
# [211] "SC34" "SC35" "SC36" "SC37" "SC38" "SC39" "SC40" "SC41" "SC42" "SC43"
# [221] "SC44" "SC45" "SC46" "SC47" "SC48" "SC49" "SC50" "SC52" "SC53" "SC54"
# [231] "SC55" "SC56" "SC57" "SC58" "SC59" "SC60" "SC61" "SC62" "SC63" "SC64"
# [241] "SC66" "SC68" "SC69" "SC70" "SC71" "SC73" "SC74" "SC75" "SC76" "SC77"
# [251] "SC78" "SC79" "SC80" "SC81" "SC83" "SC84" "SC85" "SC87" "SC88" "SC89"
# [261] "SC92" "SC93" "SC94" "SC95" "SC96" NA     NA     NA     NA     NA
# [271] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [281] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [291] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [301] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [311] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [321] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [331] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [341] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [351] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [361] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [371] NA     NA     NA     NA     NA     NA     NA     NA     NA     NA
# [381] NA     NA     NA     NA     NA     NA

# %%
df0@meta.data$Region<-c(extracted, extracted2,my_string3)

# [119] "ref_Exc.L3.5.FEZF2.DCN"         "ref_Exc.L6.FEZF2.ETV4"
# [121] "ref_Exc.L5.6.FEZF2.RSAD2"       "ref_Inh.L1.ADARB2.DISP2"
# [123] "ref_Inh.L5.6.LAMP5.SFTA3"       "ref_Exc.L6.FEZF2.TBC1D26"
# [125] "ref_Inh.L4.5.PVALB.TRIM67"

# %%
df0@meta.data[!(df0@meta.data$Region%in%c("PL01.Frontal","PL01_Frontal","PL02_Temporal","PL03_Hippocampus")),]$Region<-"Ref"

# %%
df0@meta.data[df0@meta.data$Region=="PL01.Frontal",]$Region<-"PL01_Frontal"

# %%
Idents(df0)<-"Region"

# %%
df0[["percent.mt"]] <- PercentageFeatureSet(df0, pattern = "^MT-")

# %%
options(repr.plot.width=10, repr.plot.height=5)
VlnPlot(df0,
        log = T, 
        features = c("nFeature_RNA", "nCount_RNA", "percent.mt"), 
        group.by = "Region", 
        pt.size=0.2,
        ncol = 3)
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=5)
plot1 <- FeatureScatter(df0, feature1 = "nCount_RNA", feature2 = "percent.mt")
plot2 <- FeatureScatter(df0, feature1 = "nCount_RNA", feature2 = "nFeature_RNA")
plot1 + plot2
# Out:
# plot without title

# %%
protein_coding <- read.csv("/projects/ps-gleesonlab7/gleeson3/user/zhen/data/snARseq/HEK/2019-12-25_GRCh38-95_auto_protein_coding_genes.csv",
                           header = T, row.names = 1)

# %%
df0 <- df0[protein_coding$gene_name,]

# %%
options(repr.plot.width=15, repr.plot.height=5)
plot1 <- FeatureScatter(df0, feature1 = "nCount_RNA", feature2 = "percent.mt")
plot2 <- FeatureScatter(df0, feature1 = "nCount_RNA", feature2 = "nFeature_RNA")
plot1 + plot2
# Out:
# plot without title

# %%
#write.csv(df0@meta.data[df0@meta.data$experiment=="bioskryb",],"bioskryb_comparison_unfiltered.csv")

# %%
saveRDS(df0,"Bioskryb_snRNAseq_with_ref.rds")

# %%
df0<-readRDS("Bioskryb_snRNAseq_with_ref.rds")

# %%
df0 <- subset(df0, subset = nFeature_RNA > 500 & nCount_RNA>1000 & percent.mt<30)
options(repr.plot.width=10, repr.plot.height=7)
VlnPlot(df0, features = c("nFeature_RNA", "nCount_RNA", "percent.mt"), group.by = "orig.ident", ncol = 3, pt.size = 0.2,log = T)
# Out:
# plot without title

# %%
merge<-df0

# %%
df0 <- SCTransform(object = df0, vars.to.regress = c("percent.mt","nCount_RNA","nFeature_RNA") , verbose = FALSE)

# %%
hvg <- VariableFeatures(df0)

# %%
top10 <- head(VariableFeatures(df0), 10)

# %%
plot1 <- VariableFeaturePlot(df0)
plot1
# Out:
# plot without title

# %%
df0 <- RunPCA(df0, npcs = 100, ndims.print = 1:5, nfeatures.print = 10)
# Out:
# PC_ 1
# Positive:  PTGDS, SLC1A3, NCKAP5, QKI, DOCK5, TMEM144, ZCCHC24, PHLDB1, GSN, FBXL7
# Negative:  FBXW7, FOXH1, NRGN, KIFC2, SLITRK5, NSD3, NPTX1, GRIN1, DOC2A, AHI1
# PC_ 2
# Positive:  CXCL14, SLC6A1, KIT, GAD2, ADARB2, GRIK1, PROX1, ERBB4, IGF1, DLX1
# Negative:  NRGN, ARAP2, NPTX1, RAPGEF5, FBXW7, TESPA1, CADPS2, SLC38A11, SEC14L5, SYNJ2
# PC_ 3
# Positive:  SLC6A1, SLC1A3, ADGRV1, CST3, PTGDS, ATP1A2, BCAN, ZMAT1, SLC1A2, ECPAS
# Negative:  NKTR, CCDC88A, PCLO, CCAR1, EIF5B, ZC3H13, ERBIN, TAF1D, AHI1, ERC2
# PC_ 4
# Positive:  PLEKHH1, SHTN1, PLP1, TMEM165, PIGH, CDK18, LAMP2, MOBP, MIGA1, CLDND1
# Negative:  CST3, ATP1A2, SLC1A2, SPARCL1, FGFR3, HIF3A, ITPR2, GJA1, PTPRZ1, AGT
# PC_ 5
# Positive:  VARS2, FMNL3, GGCX, ELK4, RFNG, PLEKHG5, TMEM259, LENG8, CFAP298, TRMT9B
# Negative:  AHI1, MEIS2, RBBP6, DOP1A, ZNF638, ANKRD12, NKTR, ANKRD26, TTC14, ZC3H13

# %%
options(repr.plot.width=5, repr.plot.height=5)
ElbowPlot(df0, ndims = 100)
# Out:
# plot without title

# %%
plan(strategy = "multicore")
df0 <- RunUMAP(df0,
               n.neighbors = 50,
               min.dist = 0.1,
               metric = 'cosine',
               n.components = 2, 
               dims = 1:4, 
               n.epochs = 100,
               verbose = F)
#df1 <- RunUMAP(df1, min.dist = 0.1, dims = c(1:20), n.components = 2, verbose = F)
plan(strategy = "sequential")

# %%
#df0 <- FindNeighbors(object = df0, k.param = 20, reduction = 'umap', dims = 1:2, verbose = F)
df0 <- FindNeighbors(df0, reduction = 'pca', dims =c(1:4), verbose = F)

# %%
df0 <- FindClusters(object = df0, resolution = 0.5)
# Out:
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 346
# Number of edges: 9042
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.8118
# Number of communities: 5
# Elapsed time: 0 seconds

# %%
df0
# Out:
# An object of class Seurat
# 35085 features across 346 samples within 2 assays
# Active assay: SCT (15798 features, 3000 variable features)
#  1 other assay present: RNA
#  2 dimensional reductions calculated: pca, umap

# %%
options(repr.plot.width=8, repr.plot.height=7)
DimPlot(df0,reduction = 'umap',pt.size=3, group.by =c('seurat_clusters'),label = F)
options(repr.plot.width=8, repr.plot.height=7)
DimPlot(df0,reduction = 'umap',pt.size=3, group.by =c('Region'),label = F)
# Out:
# plot without title
# plot without title

# %%
pdf(file="./UMAP_Region.pdf",width=10,height=8)
DimPlot(df0,reduction = 'umap',pt.size=3, group.by =c('Region'),label = F)
dev.off()
pdf(file="./UMAP_cluster.pdf",width=9,height=8)
DimPlot(df0,reduction = 'umap',pt.size=3, group.by =c('seurat_clusters'),label = F)
dev.off()
# Out:
# png
#   2
# png
#   2

# %%
options(repr.plot.width=20, repr.plot.height=5)
DimPlot(df0,reduction = 'umap',pt.size=3, group.by =c('seurat_clusters'), split.by=c("Region"),label = F)
# Out:
# plot without title

# %%
options(repr.plot.width=8, repr.plot.height=8)

FeaturePlot(df0,
                     slot = 'data',
                     pt.size = 1,
                     reduction = "umap",
                     combine = F,
                     min.cutoff = 'q15',
                    # max.cutoff = 'q99',
                    order = T,
                    features = c('percent.mt'))
# Out:
# [[1]]
# plot without title

# %%
rm(plist)
plist <- FeaturePlot(df0,
                     slot = 'data',
                     pt.size = 1,
                     reduction = "umap",
                     combine = F,
                     min.cutoff = 'q15',
                    # max.cutoff = 'q99',
                    order = T,
                    features = c('SYT1','RBFOX3','CAMK2A','CUX2','SATB2','RORB','TLE4',
                                 'GAD1','GAD2','GRIK1','ERBB4','NR2F2','VIP',
                                 'GFAP','SLC1A2','SLC1A3','MMD2',
                                 'OLIG2','MOBP','PLP1','PDGFRA',
                                 'SPI1'
                       ))

# %%
for(i in 1:length(plist)){
    plist[[i]] <- plist[[i]] +
                scale_color_gradientn(colours = c('grey90',RColorBrewer::brewer.pal(n = 9,name = 'YlOrRd'))) +
                NoLegend() + 
                NoAxes()
}
# Out:
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.

# %%
options(repr.plot.width=13, repr.plot.height=17)
do.call(gridExtra::grid.arrange, plist)
# Out:
# plot without title

# %%
df0.markers <- FindAllMarkers(df0, only.pos = TRUE, min.pct = 0.25, logfc.threshold = 0.25)
# Out:
# Calculating cluster 0
#
# For a more efficient implementation of the Wilcoxon Rank Sum Test,
# (default method for FindMarkers) please install the limma package
# --------------------------------------------
# install.packages('BiocManager')
# BiocManager::install('limma')
# --------------------------------------------
# After installation of limma, Seurat will automatically use the more
# efficient implementation (no further action necessary).
# This message will be shown once per session
#
# Calculating cluster 1
#
# Calculating cluster 2
#
# Calculating cluster 3
#
# Calculating cluster 4

# %%
df0.markers %>% group_by(cluster) %>% top_n(n = 10, wt = avg_log2FC)
# Out:
#    p_val        avg_log2FC pct.1 pct.2 p_val_adj    cluster gene
# 1  3.394340e-24 0.9194696  0.789 0.195 5.362378e-20 0       SLC17A7
# 2  1.434436e-23 0.9686392  0.863 0.247 2.266121e-19 0       NRGN
# 3  2.176621e-22 0.8742531  0.589 0.100 3.438626e-18 0       KCNA1
# 4  5.020378e-22 0.9100199  0.505 0.064 7.931192e-18 0       TESPA1
# 5  1.360964e-20 0.9040738  0.611 0.127 2.150051e-16 0       MLIP
# 6  3.939182e-20 0.8901427  0.747 0.203 6.223120e-16 0       NPTX1
# 7  2.024382e-19 0.8841325  0.611 0.159 3.198119e-15 0       PTK2B
# 8  8.640425e-18 0.8381778  0.547 0.124 1.365014e-13 0       ANO3
# 9  2.289734e-17 0.8616640  0.600 0.147 3.617322e-13 0       SV2B
# 10 2.692158e-14 0.8660506  0.600 0.219 4.253071e-10 0       CADPS2
# 11 4.982026e-25 1.1597709  0.876 0.257 7.870605e-21 1       SLC6A1
# 12 8.304591e-21 1.1011739  0.742 0.245 1.311959e-16 1       GRIK1
# 13 9.848814e-18 0.9502923  0.596 0.148 1.555916e-13 1       GAD2
# 14 1.386201e-15 0.7622274  0.562 0.140 2.189920e-11 1       DLX1
# 15 3.217449e-14 0.8441839  0.618 0.222 5.082926e-10 1       NRIP3
# 16 8.899495e-14 0.8553535  0.596 0.187 1.405942e-09 1       MAF
# 17 4.814777e-13 0.9390528  0.528 0.160 7.606385e-09 1       CXCL14
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# plot without title

# %%
pdf(file="./DEG_heatmap.pdf",width=8,height=5)
DoHeatmap(df0, slot = "data", features = top10$gene) + scale_fill_gradientn(colors = c("white", "red"))
dev.off()
# Out:
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# png
#   2

# %%
saveRDS(df0, "./Bioskryb_snRNAseq_with_ref.rds")

# %% [markdown]
# # Cell type assignment

# %%
df0@meta.data$Cell_Type[df0@meta.data$seurat_clusters %in% c(0,2)]<-"ExN"
df0@meta.data$Cell_Type[df0@meta.data$seurat_clusters %in% c(1,4)]<-"InN"
df0@meta.data$Cell_Type[df0@meta.data$seurat_clusters %in% c(3)]<-"Other"

# %%
options(repr.plot.width=8, repr.plot.height=7)
DimPlot(df0,reduction = 'umap',pt.size=3, group.by =c('Cell_Type'),label = F)
# Out:
# plot without title

# %%
pdf(file="./UMAP_Cell_Type.pdf",width=8,height=7)
DimPlot(df0,reduction = 'umap',pt.size=3, group.by =c('Cell_Type'),label = F)
dev.off()
# Out:
# png
#   2

# %%
Idents(df0)<-"Cell_Type"

# %%
df0.markers <- FindAllMarkers(df0, only.pos = TRUE, min.pct = 0.25, logfc.threshold = 0.25)
# Out:
# Calculating cluster ExN
#
# For a more efficient implementation of the Wilcoxon Rank Sum Test,
# (default method for FindMarkers) please install the limma package
# --------------------------------------------
# install.packages('BiocManager')
# BiocManager::install('limma')
# --------------------------------------------
# After installation of limma, Seurat will automatically use the more
# efficient implementation (no further action necessary).
# This message will be shown once per session
#
# Calculating cluster Other
#
# Calculating cluster InN

# %%
df0.markers %>% group_by(cluster) %>% top_n(n = 10, wt = avg_log2FC)
# Out:
#    p_val        avg_log2FC pct.1 pct.2 p_val_adj    cluster gene
# 1  2.597572e-32 1.2644680  0.718 0.101 4.103645e-28 ExN     NRGN
# 2  1.476873e-29 1.1684077  0.633 0.059 2.333163e-25 ExN     NPTX1
# 3  4.116849e-26 0.9972783  0.616 0.089 6.503798e-22 ExN     SLC17A7
# 4  2.861055e-22 0.9522840  0.672 0.172 4.519894e-18 ExN     ENC1
# 5  6.501468e-20 0.8842244  0.701 0.284 1.027102e-15 ExN     SYT7
# 6  2.066079e-19 0.9181759  0.463 0.047 3.263991e-15 ExN     MLIP
# 7  7.713698e-19 0.8849658  0.492 0.077 1.218610e-14 ExN     SATB2
# 8  3.528187e-18 0.8853497  0.672 0.266 5.573830e-14 ExN     LMO4
# 9  6.055273e-18 0.8855593  0.463 0.071 9.566121e-14 ExN     SV2B
# 10 1.662159e-16 0.8790329  0.480 0.095 2.625878e-12 ExN     HTR2A
# 11 2.241451e-28 1.3032427  0.500 0.020 3.541044e-24 Other   SLC1A3
# 12 3.962970e-22 1.0224757  0.413 0.020 6.260700e-18 Other   ZCCHC24
# 13 2.642759e-19 1.0520032  0.543 0.073 4.175031e-15 Other   DOCK5
# 14 2.064340e-18 0.9728935  0.522 0.073 3.261245e-14 Other   DAAM2
# 15 1.808403e-17 1.1687235  0.543 0.093 2.856916e-13 Other   PTGDS
# 16 2.487419e-11 1.3657395  0.457 0.103 3.929625e-07 Other   PLP1
# 17 7.309096e-10 0.9286226  0.587 0.230 1.154691e-05 Other   PHLDB1
# 18 4.666902e-08 0.9825761  0.370 0.100 7.372772e-04 Other   MOBP
# 19 1.538614e-07 1.0332670  0.370 0.107 2.430703e-03 Other   CLMN
# 20 1.243226e-04 0.9173223  0.348 0.160 1.000000e+00 Other   TMEM144
# 21 9.663720e-44 1.4757422  0.902 0.148 1.526674e-39 InN     SLC6A1
# 22 4.060750e-39 1.3452357  0.675 0.036 6.415173e-35 InN     GAD2
# 23 6.161899e-36 1.3463970  0.789 0.143 9.734569e-32 InN     GRIK1
# 24 7.671259e-36 1.2716223  0.659 0.054 1.211905e-31 InN     GAD1
# 25 3.700958e-35 1.1277013  0.569 0.004 5.846773e-31 InN     IGF1
# 26 2.837879e-34 1.4632640  0.634 0.045 4.483281e-30 InN     CXCL14
# 27 2.384775e-30 1.1031725  0.683 0.126 3.767468e-26 InN     NRIP3
# 28 2.849387e-29 1.1756808  0.650 0.094 4.501461e-25 InN     MAF
# 29 3.533677e-26 1.2216013  0.618 0.112 5.582503e-22 InN     ADARB2
# 30 1.531568e-25 1.1791515  0.756 0.300 2.419571e-21 InN     ERBB4

# %%
top10 <- df0.markers %>% group_by(cluster) %>% top_n(n = 10, wt = avg_log2FC)
options(repr.plot.width=7, repr.plot.height=5)
DoHeatmap(df0, slot = "data", features = top10$gene) + scale_fill_gradientn(colors = c("white", "red"))
# Out:
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# plot without title

# %%
pdf(file="./DEG_heatmap_Celltype_defined.pdf",width=8,height=5)
DoHeatmap(df0, slot = "data", features = top10$gene) + scale_fill_gradientn(colors = c("white", "red"))
dev.off()
# Out:
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# png
#   2

# %% [markdown]
# # Subsetting for interneuron details

# %%
df1<-subset(df0, seurat_clusters %in% c(1,4))

# %%
df1 <- SCTransform(object = df1, vars.to.regress = c("percent.mt","nCount_RNA","nFeature_RNA") , verbose = FALSE)

# %%
hvg <- VariableFeatures(df1)

# %%
top10 <- head(VariableFeatures(df1), 10)

# %%
plot1 <- VariableFeaturePlot(df1)
plot1
# Out:
# plot without title

# %%
df1 <- RunPCA(df1, npcs = 100, ndims.print = 1:5, nfeatures.print = 10)
# Out:
# Warning message in irlba(A = t(x = object), nv = npcs, ...):
# “You're computing too large a percentage of total singular values, use a standard svd instead.”
# PC_ 1
# Positive:  PCLO, ANKRD26, NKTR, SRSF11, RBBP6, ANKRD36C, MYH10, ARHGAP21, EPHB6, SSX2IP
# Negative:  RPH3A, SOX1, ECPAS, FMNL3, CCP110, SHTN1, SLC6A1, BACH1, LENG8, TMEM97
# PC_ 2
# Positive:  SYT1, EYA4, SV2C, GOLIM4, HOMER2, KIT, BCL11B, B3GALT2, TRPC3, AP2A2
# Negative:  NR2F2, N4BP2, TSHZ2, RYR3, COL21A1, EEF2K, TUT4, HDGFL3, PLCE1, CHD4
# PC_ 3
# Positive:  RELN, RC3H1, PMEPA1, MTHFD1, SV2C, CACNA2D1, MGAT4C, RPS6KA5, FAM217B, RGS6
# Negative:  HAX1, GPN2, SPARCL1, KIAA0930, NUBP1, DIAPH1, MAPK1IP1L, PHYKPL, TRIM27, PEX1
# PC_ 4
# Positive:  NECAB1, CCK, PPP1R3E, DPP7, SET, CCSAP, ILF3, ZNF362, CXCL14, PRPF39
# Negative:  KCNT1, LZTS3, HMGCL, TXNDC15, SP4, KRR1, KLHL3, NPHP3, GOLGB1, SMAD2
# PC_ 5
# Positive:  CXCL14, CNR1, B3GAT1, HLA-A, PWWP2A, VIP, PROX1, KIT, ARPP21, CAMK4
# Negative:  SATB1, SOX6, SPARCL1, DECR1, LHX6, VGLL4, ST8SIA4, PHACTR2, TSHZ3, SLIT2

# %%
options(repr.plot.width=5, repr.plot.height=5)
ElbowPlot(df1, ndims = 100)
# Out:
# plot without title

# %%
plan(strategy = "multicore")
df1 <- RunUMAP(df1,
               n.neighbors = 50,
               min.dist = 0.1,
               metric = 'cosine',
               n.components = 2, 
               dims = 1:4, 
               #n.epochs = 100,
               verbose = F)
#df1 <- RunUMAP(df1, min.dist = 0.1, dims = c(1:20), n.components = 2, verbose = F)
plan(strategy = "sequential")

# %%
#df1 <- FindNeighbors(object = df1, k.param = 20, reduction = 'umap', dims = 1:2, verbose = F)
df1 <- FindNeighbors(df1, reduction = 'pca', dims =c(1:4), verbose = F)

# %%
df1 <- FindClusters(object = df1, resolution = 0.99)
# Out:
# Modularity Optimizer version 1.3.0 by Ludo Waltman and Nees Jan van Eck
#
# Number of nodes: 123
# Number of edges: 3348
#
# Running Louvain algorithm...
# Maximum modularity in 10 random starts: 0.4643
# Number of communities: 4
# Elapsed time: 0 seconds

# %%
options(repr.plot.width=8, repr.plot.height=7)
DimPlot(df1,reduction = 'umap',pt.size=3, group.by =c('seurat_clusters'),label = F)
options(repr.plot.width=8, repr.plot.height=7)
DimPlot(df1,reduction = 'umap',pt.size=3, group.by =c('Region'),label = F)
# Out:
# plot without title
# plot without title

# %%
rm(plist)
plist <- FeaturePlot(df1,
                     slot = 'data',
                     pt.size = 1,
                     reduction = "umap",
                     combine = F,
                     min.cutoff = 'q15',
                    # max.cutoff = 'q99',
                    order = T,
                    features = c('SYT1','RBFOX3','CAMK2A','CUX2','SATB2','RORB','TLE4',
                                 'GAD1','GAD2','GRIK1','ERBB4','NR2F2','VIP',
                                 'GFAP','SLC1A2','SLC1A3','MMD2',
                                 'OLIG2','MOBP','PLP1','PDGFRA',
                                 'SPI1'
                       ))
# Out:
# Warning message:
# “Could not find OLIG2 in the default search locations, found in RNA assay instead”
# Warning message in FeaturePlot(df1, slot = "data", pt.size = 1, reduction = "umap", :
# “All cells have the same value (2) of rna_OLIG2.”

# %%
for(i in 1:length(plist)){
    plist[[i]] <- plist[[i]] +
                scale_color_gradientn(colours = c('grey90',RColorBrewer::brewer.pal(n = 9,name = 'YlOrRd'))) +
                NoLegend() + 
                NoAxes()
}
# Out:
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.
# Scale for colour is already present.
# Adding another scale for colour, which will replace the existing scale.

# %%
options(repr.plot.width=13, repr.plot.height=17)
do.call(gridExtra::grid.arrange, plist)
# Out:
# plot without title

# %% [markdown]
# # Print cell type information

# %%
df0<-readRDS("./Bioskryb_snRNAseq_with_ref.rds")

# %%
metadata<-read.table("./Bioskryb_RNA_cell_type_info_with_ref.txt",header=TRUE)

# %%
df0@meta.data
# Out:
#                                                                                                                                                                                               orig.ident
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.S
# ref_Inh.L1.3.VIP.CCDC184                                                                                                                                                                      NA
# ref_Exc.L5.6.THEMIS.GPR21                                                                                                                                                                     NA
# ref_Exc.L4.5.RORB.RPL31P31                                                                                                                                                                    NA
# ref_Exc.L6.THEMIS.LINC00343                                                                                                                                                                   NA
# ref_Inh.L1.3.PAX6.NABP1                                                                                                                                                                       NA
# ref_Inh.L1.5.VIP.KCNJ2                                                                                                                                                                        NA
# ref_Inh.L2.4.VIP.LGI2                                                                                                                                                                         NA
# ref_Inh.L1.4.LAMP5.DUSP4                                                                                                                                                                      NA
# ref_Exc.L2.4.RORB.GRIK1                                                                                                                                                                       NA
# ref_Oligo.L4.6.OPALIN                                                                                                                                                                         NA
# ref_Exc.L3.THEMIS.PLA2G7                                                                                                                                                                      NA
# ref_Exc.L5.RORB.SNHG7                                                                                                                                                                         NA
# ...
# ref_Exc.L2.4.RORB.GRIK1                                                                                                                                                                       0
# ref_Oligo.L4.6.OPALIN                                                                                                                                                                         3
# ref_Exc.L3.THEMIS.PLA2G7                                                                                                                                                                      0
# ref_Exc.L5.RORB.SNHG7                                                                                                                                                                         0
# ref_Astro.L1.6.FGFR3.ETNPPL                                                                                                                                                                   3
# ref_Exc.L4.RORB.CACNG5                                                                                                                                                                        2
# ref_Exc.L6.FEZF2.FAM95C                                                                                                                                                                       0
# ref_Inh.L1.3.VIP.GGH                                                                                                                                                                          4
# ref_Exc.L3.5.FEZF2.DCN                                                                                                                                                                        0
# ref_Exc.L6.FEZF2.ETV4                                                                                                                                                                         0
# ref_Exc.L5.6.FEZF2.RSAD2                                                                                                                                                                      2
# ref_Inh.L1.ADARB2.DISP2                                                                                                                                                                       1
# ref_Inh.L5.6.LAMP5.SFTA3                                                                                                                                                                      4
# ref_Exc.L6.FEZF2.TBC1D26                                                                                                                                                                      0
# ref_Inh.L4.5.PVALB.TRIM67                                                                                                                                                                     1
#                                                                                                                                                                                               seurat_clusters
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC01_S1.PL01.Frontal.RNA.SC01_S1.Aligned.sortedByCoord.out.bam   2
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC02_S2.PL01.Frontal.RNA.SC02_S2.Aligned.sortedByCoord.out.bam   2
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC03_S3.PL01.Frontal.RNA.SC03_S3.Aligned.sortedByCoord.out.bam   3
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC04_S4.PL01.Frontal.RNA.SC04_S4.Aligned.sortedByCoord.out.bam   1
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC05_S5.PL01.Frontal.RNA.SC05_S5.Aligned.sortedByCoord.out.bam   1
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC07_S6.PL01.Frontal.RNA.SC07_S6.Aligned.sortedByCoord.out.bam   2
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC08_S7.PL01.Frontal.RNA.SC08_S7.Aligned.sortedByCoord.out.bam   3
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC09_S8.PL01.Frontal.RNA.SC09_S8.Aligned.sortedByCoord.out.bam   3
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC10_S9.PL01.Frontal.RNA.SC10_S9.Aligned.sortedByCoord.out.bam   1
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC11_S10.PL01.Frontal.RNA.SC11_S10.Aligned.sortedByCoord.out.bam 3
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC12_S11.PL01.Frontal.RNA.SC12_S11.Aligned.sortedByCoord.out.bam 2
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.SC13_S12.PL01.Frontal.RNA.SC13_S12.Aligned.sortedByCoord.out.bam 0
# bioskryb_7669_F1_X.projects.ps.gleesonlab8.User.arzoo.20230706_Changuk_7669RF1_Bioskryb_RNA_IGM.output.star.PL01.Frontal.RNA.S
# 328 ref_Inh.L1.3.PAX6.NABP1      0           27502      7025
# 329 ref_Inh.L1.5.VIP.KCNJ2       0           25989      5960
# 330 ref_Inh.L2.4.VIP.LGI2        0           25790      5859
# 331 ref_Inh.L1.4.LAMP5.DUSP4     0           26030      5985
# 332 ref_Exc.L2.4.RORB.GRIK1      0           27446      6994
# 333 ref_Oligo.L4.6.OPALIN        0           21395      3465
# 334 ref_Exc.L3.THEMIS.PLA2G7     0           29459      8305
# 335 ref_Exc.L5.RORB.SNHG7        0           29108      8121
# 336 ref_Astro.L1.6.FGFR3.ETNPPL  0           23278      4579
# 337 ref_Exc.L4.RORB.CACNG5       0           25818      5775
# 338 ref_Exc.L6.FEZF2.FAM95C      0           27702      7146
# 339 ref_Inh.L1.3.VIP.GGH         0           24906      5350
# 340 ref_Exc.L3.5.FEZF2.DCN       0           28656      7692
# 341 ref_Exc.L6.FEZF2.ETV4        0           27911      7248
# 342 ref_Exc.L5.6.FEZF2.RSAD2     0           26732      6465
# 343 ref_Inh.L1.ADARB2.DISP2      0           26885      6384
# 344 ref_Inh.L5.6.LAMP5.SFTA3     0           26463      6287
# 345 ref_Exc.L6.FEZF2.TBC1D26     0           27813      7151
# 346 ref_Inh.L4.5.PVALB.TRIM67    0           25632      5630
#     SCT_snn_res.0.5 seurat_clusters Cell_Type Marked_InN
# 1   2               2               ExN       0
# 2   2               2               ExN       0
# 3   3               3               Other     0
# 4   1               1               InN       0
# 5   1               1               InN       0
# 6   2               2               ExN       0
# 7   3               3               Other     0
# 8   3               3               Other     0
# 9   1               1               InN       0
# 10  3               3               Other     0
# 11  2               2               ExN       0
# 12  0               0               ExN       0
# 13  2               2               ExN       0
# 14  0               0               ExN       0
# 15  1               1               InN       0
# 16  3               3               Other     0
# 17  3               3               Other     0
# 18  2               2               ExN       0
# 19  3               3               Other     0
# 20  2               2               ExN       0
# 21  1               1               InN       1
# 22  2               2               ExN       0
# 23  4               4               InN       1
# 24  2               2               ExN       0
# 25  2               2               ExN       0
# 26  2               2               ExN       0
# 27  1               1               InN       1
# 28  2               2               ExN       0
# 29  4               4               InN       1
# 30  2               2               ExN       0
# ⋮   ⋮               ⋮               ⋮         ⋮
# 317 0               0               ExN       0
# 318 1               1               InN       0
# 319 4               4               InN       0
# 320 1               1               InN       0
# 321 0               0               ExN       0
# 322 4               4               InN       0
# 323 4               4               InN       0
# 324 4               4               InN       0
# 325 0               0               ExN       0
# 326 2               2               ExN       0
# 327 0               0               ExN       0
# 328 1               1               InN       0
# 329 4               4               InN       0
# 330 4               4               InN       0
# 331 4               4               InN       0
# 332 0               0               ExN       0
# 333 3               3               Other     0
# 334 0               0               ExN       0
# 335 0               0               ExN       0
# 336 3               3               Other     0
# 337 2               2               ExN       0
# 338 0               0               ExN       0
# 339 4               4               InN       0
# 340 0               0               ExN       0
# 341 0               0               ExN       0
# 342 2               2               ExN       0
# 343 1               1               InN       0
# 344 4               4               InN       0
# 345 0               0               ExN       0
# 346 1               1               InN       0
