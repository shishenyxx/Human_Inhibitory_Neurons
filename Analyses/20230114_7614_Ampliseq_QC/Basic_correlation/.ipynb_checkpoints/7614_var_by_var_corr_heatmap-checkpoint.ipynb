# %%
library(ggplot2)
library(dplyr)
library(gplots)
library(reshape2)
library(umap)
library(patchwork)
library(ggExtra) 
library(pals)
library(RColorBrewer)
library(heatmap.plus)
filtered <- read.table("../7614_final_summary_anno3.txt",header=T,sep="\t")
variant_list <- read.csv("../variant_annotation/287_variant_annotation.csv",header=T,sep=",", row.names = 1)

# %%
filtered$Punch<-as.character(filtered$Punch)
filtered$Note<-as.character(filtered$Note)

# %%
mosaic_filtered <- filtered[filtered$Mosaic_shared_btw_WGS_Amp==1,] 
#shared_variant_list<-variant_list[variant_list$sample_number_presented>1,]
#shared_variant_list<-shared_variant_list[shared_variant_list$CTX_only==1,] # cortex only shared variant annotation table
#shared_mosaic_filtered<-mosaic_filtered[mosaic_filtered$CHROM.POS.REF.ALT %in% rownames(shared_variant_list),]
# brain_only_shared_mosaic_filtered<-shared_mosaic_filtered[shared_mosaic_filtered$CHROM.POS.REF.ALT %in% shared_variant_list[shared_variant_list$CTX_only=='1',]$variant_list,]

# output: shared/validated variant's MAF with sample and other annotation.

# %%
length(unique(mosaic_filtered$CHROM.POS.REF.ALT))
#length(unique(shared_variant_list$variant_list))
#length(unique(shared_mosaic_filtered$CHROM.POS.REF.ALT))
# Out:
# [1] 287

# %%
# taking a subset of samples
melt_mtcars<-mosaic_filtered[,c("ID", "CHROM.POS.REF.ALT", "MAF", "Hemisphere", "Organ", "Region","Bulk_main", "Sort_main", "Cell_Type","Note")]
melt_mtcars<-melt_mtcars[melt_mtcars$Bulk_main==1,]
#melt_mtcars<-melt_mtcars[melt_mtcars$ID %in% c('7614-L-9-Ins-COUPTF2','7614-L-9-Ins-DLX1','7614-L-9-Ins-TBR1','7614-L-O-COUPTF2','7614-L-O-DLX1','7614-L-O-TBR1',
#                                              '7614-L-T-COUPTF2','7614-L-T-DLX1','7614-L-T-TBR1','7614-R-5-Ins-COUPTF2','7614-R-5-Ins-DLX1','7614-R-5-Ins-TBR1',
#                                               '7614-R-F-COUPTF2','7614-R-F-DLX1','7614-R-F-TBR1','7614-R-O-COUPTF2','7614-R-O-DLX1','7614-R-O-TBR1',
#                                               '7614-R-T-COUPTF2','7614-R-T-DLX1','7614-R-T-TBR1'),]
#melt_mtcars<-melt_mtcars[!melt_mtcars$ID %in% c('JGG','JGG-bulk','JGG-sorted'),]
# melt_mtcars<-melt_mtcars[melt_mtcars$Cell_Type %in% c('TBR1'),]
# melt_mtcars<-melt_mtcars[melt_mtcars$Hemisphere %in% c('L'),]
# melt_mtcars<-melt_mtcars[(melt_mtcars$Organ %in% c('CTX','BG','AMG','HIP','THAL','SUB','CLO','CB','Kidney','Liver')),]
#melt_mtcars<-melt_mtcars[melt_mtcars$Note %in% c('SMALL'),]

#melt_mtcars<-melt_mtcars[melt_mtcars$Cell_Type %in% c('Bulk'),]
#melt_mtcars<-melt_mtcars[(melt_mtcars$Organ %in% c('CTX','BG')),]
#melt_mtcars<-melt_mtcars[melt_mtcars$Region %in% c('P','T','O','Ins','PF','F'),]
#melt_mtcars<-melt_mtcars[melt_mtcars$Punch %in% c('1'),]
melt_mtcars$MAF <- sqrt(melt_mtcars$MAF)
nrow(melt_mtcars)
# Out:
# [1] 10045

# %%
unique(melt_mtcars$CHROM.POS.REF.ALT)
# Out:
#   [1] "1-31691734-G-A"        "1-45675887-A-C"        "1-64512024-C-T"
#   [4] "1-98426749-G-A"        "1-99581604-C-G"        "1-106934533-C-T"
#   [7] "1-168467950-G-A"       "1-169329191-G-A"       "1-180856518-T-G"
#  [10] "1-188748555-G-A"       "1-212352377-G-T"       "1-221888654-T-C"
#  [13] "1-239397797-T-A"       "1-240507547-A-T"       "1-241434408-C-T"
#  [16] "2-1519264-AAC-A"       "2-5965706-G-A"         "2-8566334-G-T"
#  [19] "2-24960206-G-A"        "2-34606921-T-A"        "2-49268814-A-C"
#  [22] "2-53799113-A-T"        "2-56448245-G-A"        "2-71776656-C-A"
#  [25] "2-90231584-G-T"        "2-97358394-C-T"        "2-99501908-C-T"
#  [28] "2-101097017-C-T"       "2-119890951-G-A"       "2-138583113-G-A"
#  [31] "2-139753954-C-T"       "2-142968696-G-T"       "2-143727379-C-T"
#  [34] "2-170746611-A-G"       "2-189956910-G-A"       "2-194793292-CTT-C"
#  [37] "2-195046625-G-A"       "2-200153645-G-T"       "2-209589692-G-A"
# ...

# %%
#dcasting with labeling
casted_MAF_VarBySample <- dcast(melt_mtcars, ID~CHROM.POS.REF.ALT, value.var = "MAF", rm.na=T)
rownames(casted_MAF_VarBySample) <- casted_MAF_VarBySample$ID # change rownames to ID
casted_MAF_VarBySample2 <- casted_MAF_VarBySample[,-1] # remove ID column
nrow(casted_MAF_VarBySample2) # row number 
head(casted_MAF_VarBySample2)
# Out:
# [1] 35
#                     1-106934533-C-T 1-168467950-G-A 1-169329191-G-A
# 7614-B-L-T          0.09245307      0.01714770      0.06865979
# 7614-C-R-2          0.16206815      0.02894197      0.01609401
# 7614-C-R-3          0.13822727      0.02446312      0.01669451
# 7614-cerebellum-141 0.10055935      0.01973688      0.02186151
# 7614-heart          0.01389157      0.00996271      0.00000000
# 7614-Kidney-L-144   0.11291411      0.02064710      0.01887969
#                     1-180856518-T-G 1-188748555-G-A 1-212352377-G-T
# 7614-B-L-T          0.000000000     0.09343474      0.00837414
# 7614-C-R-2          0.048502736     0.03482081      0.01192167
# 7614-C-R-3          0.010062073     0.05566824      0.00000000
# 7614-cerebellum-141 0.012310548     0.04185053      0.01305620
# 7614-heart          0.010393573     0.10798985      0.01571672
# 7614-Kidney-L-144   0.008901999     0.09921391      0.01726758
#                     1-221888654-T-C 1-239397797-T-A 1-240507547-A-T
# ...

# %%
#remove labeling from dcasted matrix
casted_MAF_VarBySample3<-na.omit(t(casted_MAF_VarBySample2)) # Sample by variant matrix with sqrt-MAF values
var_anno<-variant_list[variant_list$variant_list %in% rownames(casted_MAF_VarBySample3),] # take variant annotation from the variants in casted_MAF_VarBySample3
casted_MAF_VarBySample3<-casted_MAF_VarBySample3[order(rownames(casted_MAF_VarBySample3)), ] # rearrange the casted_MAF_VarBySample3 matrix in order of variant name
var_anno<-var_anno[order(row.names(var_anno)), ] # rearrange the var_anno in order of variant name
casted_MAF_VarBySample3 <- cbind(casted_MAF_VarBySample3,var_anno)

# %%
label<-casted_MAF_VarBySample3[which(names(casted_MAF_VarBySample3)=='variant_list'):ncol(casted_MAF_VarBySample3)]
UMAP<-umap(casted_MAF_VarBySample3[,1:(which(names(casted_MAF_VarBySample3)=='variant_list')-1)])

# %%
UMAP<-as.data.frame(UMAP$layout)
UMAP<-cbind(UMAP,label)

# %%
names(UMAP)
# Out:
#  [1] "V1"                      "V2"
#  [3] "variant_list"            "sample_number_presented"
#  [5] "CTX"                     "CB"
#  [7] "Heart"                   "Kidney"
#  [9] "BG"                      "THAL"
# [11] "Liver"                   "L"
# [13] "R"                       "PF"
# [15] "F"                       "P"
# [17] "O"                       "T"
# [19] "Ins"                     "Cau"
# [21] "Put"                     "GP"
# [23] "Bulk"                    "DLX1"
# [25] "TBR1"                    "COUPTF2"
# [27] "NeuN"                    "LHX2"
# [29] "Olig2"                   "PU1"
# [31] "DARPP32M.NeuNP"          "DARPP32P.NeuNP"
# [33] "Cardiomyocyte"           "Brain_only"
# [35] "CTX_only"                "CTX_BG_only"
# [37] "BG_only"                 "THAL_only"
# [39] "Left_only"               "Right_only"
# [41] "L_BR_PF_only"            "L_BR_F_only"
# [43] "L_BR_P_only"             "L_BR_O_only"
# [45] "L_BR_Ins_only"           "R_BR_PF_only"
# ...

# %%
UMAP$Brain_only<-as.character(UMAP$Brain_only)
# UMAP$IN_only<-as.character(UMAP$IN_only)
UMAP$CTX_only<-as.character(UMAP$CTX_only)
UMAP$CTX_BG_only<-as.character(UMAP$CTX_BG_only)
UMAP$BG_only<-as.character(UMAP$BG_only)
UMAP$THAL_only<-as.character(UMAP$THAL_only)
UMAP$Left_only<-as.character(UMAP$Left_only)
UMAP$Right_only<-as.character(UMAP$Right_only)
# UMAP$COUP_only<-as.character(UMAP$COUP_only)
# UMAP$TBR_only<-as.character(UMAP$TBR_only)
# UMAP$TBR_BR<-as.character(UMAP$TBR_BR)
# UMAP$DLX_BR<-as.character(UMAP$DLX_BR)
# UMAP$COUP_BR<-as.character(UMAP$COUP_BR)
# UMAP$MSN_BR<-as.character(UMAP$MSN_BR)
UMAP$PF<-as.character(UMAP$PF)
UMAP$F<-as.character(UMAP$F)
UMAP$P<-as.character(UMAP$P)
UMAP$O<-as.character(UMAP$O)
UMAP$Ins<-as.character(UMAP$Ins)



# UMAP$COUPTF2_enriched<-as.character(UMAP$COUPTF2_enriched)

# %%
options(repr.plot.width=10,repr.plot.height=10)
p1<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = CTX_only, shape = Brain_only),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"),legend.position = c(0.93, 0.2))
# # variants grouping by umap
# options(repr.plot.width=10,repr.plot.height=5)
# p2<-ggplot(df, aes(x = V1, y = V2))+ 
# geom_point(
#     aes(color = Left_only),
#     size = 3.5, 
#     alpha = 1 # It's nice to add some transparency because there may be overlap.
#   )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
# panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.8))
# # variants grouping by umap
# options(repr.plot.width=10,repr.plot.height=5)
# p3<-ggplot(df, aes(x = V1, y = V2))+ 
# geom_point(
#     aes(color = Right_only),
#     size = 3.5, 
#     alpha = 1 # It's nice to add some transparency because there may be overlap.
#   )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
# panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.7))
# # variants grouping by umap
# options(repr.plot.width=10,repr.plot.height=5)
p2<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = PF),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))
# variants grouping by umap
options(repr.plot.width=10,repr.plot.height=5)
p3<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = F),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))

p4<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = P),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))

p5<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = O),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))

p6<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = Ins),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))

# %%
options(repr.plot.width=30,repr.plot.height=10)
p<-p1+scale_colour_manual(values = c('green','#3283FE','#FF5005','#2BCE48','#426600') )+
p2+scale_colour_manual(values = c('green','#3283FE',"#A6D854","#FFD92F","#6699CC","#88CCEE","#B3B3B3"))+
p3+scale_colour_manual(values = c('green','#3283FE','#85660D','#782AB6','#565656','#1C8356','#16FF32','#F7E1A0','#E2E2E2','#1CBE4F','#C4451C','#DEA0FD','#FE00FA',
                                 '#325A9B','#FEAF16','#F8A19F','#90AD1C','#F6222E','#1CFFCE','#2ED9FF','#B10DA1','#C075A6') )+
p4+scale_colour_manual(values = c('green','#3283FE','#85660D','#782AB6','#565656','#1C8356','#16FF32','#F7E1A0','#E2E2E2','#1CBE4F','#C4451C','#DEA0FD','#FE00FA',
                                  '#325A9B','#FEAF16','#F8A19F','#90AD1C','#F6222E','#1CFFCE','#2ED9FF','#B10DA1','#C075A6') )+
p5+scale_colour_manual(values = c('green','#3283FE','#85660D','#782AB6','#565656','#1C8356','#16FF32','#F7E1A0','#E2E2E2','#1CBE4F','#C4451C','#DEA0FD','#FE00FA',
                                 '#325A9B','#FEAF16','#F8A19F','#90AD1C','#F6222E','#1CFFCE','#2ED9FF','#B10DA1','#C075A6') )+
p6+scale_colour_manual(values = c('green','#3283FE','#85660D','#782AB6','#565656','#1C8356','#16FF32','#F7E1A0','#E2E2E2','#1CBE4F','#C4451C','#DEA0FD','#FE00FA',
                                 '#325A9B','#FEAF16','#F8A19F','#90AD1C','#F6222E','#1CFFCE','#2ED9FF','#B10DA1','#C075A6') )
p
# Out:
# plot without title

# %%
df1<-casted_MAF_VarBySample3[,1:(which(names(casted_MAF_VarBySample3)=='variant_list')-1)]
df1<-na.omit(df1)
df1_cor<-cor(t(df1),method = "pearson",use="na.or.complete")

# %%
write.csv(df1,"./temp.csv")

# %%
names(label)
# Out:
#  [1] "variant_list"            "sample_number_presented"
#  [3] "CTX"                     "CB"
#  [5] "Heart"                   "Kidney"
#  [7] "BG"                      "THAL"
#  [9] "Liver"                   "L"
# [11] "R"                       "PF"
# [13] "F"                       "P"
# [15] "O"                       "T"
# [17] "Ins"                     "Cau"
# [19] "Put"                     "GP"
# [21] "Bulk"                    "DLX1"
# [23] "TBR1"                    "COUPTF2"
# [25] "NeuN"                    "LHX2"
# [27] "Olig2"                   "PU1"
# [29] "DARPP32M.NeuNP"          "DARPP32P.NeuNP"
# [31] "Cardiomyocyte"           "Brain_only"
# [33] "CTX_only"                "CTX_BG_only"
# [35] "BG_only"                 "THAL_only"
# [37] "Left_only"               "Right_only"
# [39] "L_BR_PF_only"            "L_BR_F_only"
# [41] "L_BR_P_only"             "L_BR_O_only"
# [43] "L_BR_Ins_only"           "R_BR_PF_only"
# [45] "R_BR_F_only"             "R_BR_P_only"
# ...

# %%
myCol<-as.data.frame(label[,])
myCol$Brain_only_col[myCol$Brain_only %in% c("1")]<-"Black"
#myCol$COUPTF2_enriched_col[myCol$COUPTF2_enriched %in% c("1")]<-"Blue"
 myCol$Hemisphere_col[myCol$Left_only %in% c("1")]<-"Green"
 myCol$Hemisphere_col[myCol$Right_only %in% c("1")]<-"red"
# myCol$Brain_only_col[myCol$Brain_only %in% c("1")]<-"#76FFF7"
# myCol$IN_only_col[myCol$IN_only %in% c("1")]<-"Purple"
# myCol$COUP_only_col[myCol$COUP_only %in% c("1")]<-"Yellow"
# myCol$TBR_only_col[myCol$TBR_only %in% c("1")]<-"pink"

# myCol$DLX_BR_col[myCol$DLX_BR %in% c("1")]<-"grey"
# myCol$TBR_BR_col[myCol$TBR_BR %in% c("1")]<-"grey90"
# myCol$COUP_BR_col[myCol$COUP_BR %in% c("1")]<-"cyan"
myCol$T_col[(myCol$T %in% c("1") & myCol$Bulk %in% c("1") )]<-"magenta"
myCol$PF_col[(myCol$PF %in% c("1") & myCol$Bulk %in% c("1") )]<-"magenta"
myCol$F_col[(myCol$F %in% c("1") & myCol$Bulk %in% c("1") )]<-"magenta"
myCol$P_col[(myCol$P %in% c("1") & myCol$Bulk %in% c("1") )]<-"magenta"
myCol$O_col[(myCol$O %in% c("1") & myCol$Bulk %in% c("1") )]<-"magenta"
myCol$Ins_col[(myCol$Ins %in% c("1") & myCol$Bulk %in% c("1"))]<-"magenta"



myCol2<-as.matrix(cbind(myCol$Brain_only_col, myCol$Hemisphere_col,
                        #myCol$COUPTF2_enriched_col, myCol$IN_only_col, myCol$COUP_only_col,
                        #myCol$TBR_only_col, myCol$DLX_BR_col, myCol$TBR_BR_col,myCol$COUP_BR_col,
                        myCol$T_col,myCol$PF_col,myCol$F_col,myCol$P_col,myCol$O_col,myCol$Ins_col))
colnames(myCol2)<-c("Brain_only_col","Hemisphere_col",
                    #"COUPTF2_enriched_col","IN_only_col","COUP_only_col","TBR_only_col","DLX_BR_col","TBR_BR_col","COUP_BR_col",
                   "T_col","PF_col","F_col","P_col","O_col","Ins_col")

# %%
Colors = c("yellow","red")
Colors = colorRampPalette(Colors)(100)

options(repr.plot.width=20, repr.plot.height=20)

heatmap.plus(df1_cor,
             distfun = function(x) dist(x,method = 'manhattan'),
             col=Colors, 
             RowSideColors=myCol2,
             margins=c(7,7),
             scale = c("none"))
# Out:
# plot without title

# %%
# taking a subset of samples
melt_mtcars<-mosaic_filtered[,c("ID", "CHROM.POS.REF.ALT", "MAF", "Hemisphere", "Organ", "Region","Bulk_main", "Sort_main", "Cell_Type","Note")]
melt_mtcars<-melt_mtcars[melt_mtcars$Sort_main==1,]
#melt_mtcars<-melt_mtcars[melt_mtcars$ID %in% c('7614-L-9-Ins-COUPTF2','7614-L-9-Ins-DLX1','7614-L-9-Ins-TBR1','7614-L-O-COUPTF2','7614-L-O-DLX1','7614-L-O-TBR1',
#                                              '7614-L-T-COUPTF2','7614-L-T-DLX1','7614-L-T-TBR1','7614-R-5-Ins-COUPTF2','7614-R-5-Ins-DLX1','7614-R-5-Ins-TBR1',
#                                               '7614-R-F-COUPTF2','7614-R-F-DLX1','7614-R-F-TBR1','7614-R-O-COUPTF2','7614-R-O-DLX1','7614-R-O-TBR1',
#                                               '7614-R-T-COUPTF2','7614-R-T-DLX1','7614-R-T-TBR1'),]
#melt_mtcars<-melt_mtcars[!melt_mtcars$ID %in% c('JGG','JGG-bulk','JGG-sorted'),]
# melt_mtcars<-melt_mtcars[melt_mtcars$Cell_Type %in% c('TBR1'),]
# melt_mtcars<-melt_mtcars[melt_mtcars$Hemisphere %in% c('L'),]
# melt_mtcars<-melt_mtcars[(melt_mtcars$Organ %in% c('CTX','BG','AMG','HIP','THAL','SUB','CLO','CB','Kidney','Liver')),]
#melt_mtcars<-melt_mtcars[melt_mtcars$Note %in% c('SMALL'),]

#melt_mtcars<-melt_mtcars[melt_mtcars$Cell_Type %in% c('Bulk'),]
#melt_mtcars<-melt_mtcars[(melt_mtcars$Organ %in% c('CTX','BG')),]
#melt_mtcars<-melt_mtcars[melt_mtcars$Region %in% c('P','T','O','Ins','PF','F'),]
#melt_mtcars<-melt_mtcars[melt_mtcars$Punch %in% c('1'),]
melt_mtcars$MAF <- sqrt(melt_mtcars$MAF)
nrow(melt_mtcars)
# Out:
# [1] 27839

# %%
unique(melt_mtcars$CHROM.POS.REF.ALT)
# Out:
#   [1] "1-31691734-G-A"        "1-45675887-A-C"        "1-64512024-C-T"
#   [4] "1-98426749-G-A"        "1-99581604-C-G"        "1-106934533-C-T"
#   [7] "1-168467950-G-A"       "1-169329191-G-A"       "1-180856518-T-G"
#  [10] "1-188748555-G-A"       "1-212352377-G-T"       "1-221888654-T-C"
#  [13] "1-239397797-T-A"       "1-240507547-A-T"       "1-241434408-C-T"
#  [16] "2-1519264-AAC-A"       "2-5965706-G-A"         "2-8566334-G-T"
#  [19] "2-24960206-G-A"        "2-34606921-T-A"        "2-49268814-A-C"
#  [22] "2-53799113-A-T"        "2-56448245-G-A"        "2-71776656-C-A"
#  [25] "2-90231584-G-T"        "2-97358394-C-T"        "2-99501908-C-T"
#  [28] "2-101097017-C-T"       "2-119890951-G-A"       "2-138583113-G-A"
#  [31] "2-139753954-C-T"       "2-142968696-G-T"       "2-143727379-C-T"
#  [34] "2-170746611-A-G"       "2-189956910-G-A"       "2-194793292-CTT-C"
#  [37] "2-195046625-G-A"       "2-200153645-G-T"       "2-209589692-G-A"
# ...

# %%
#dcasting with labeling
casted_MAF_VarBySample <- dcast(melt_mtcars, ID~CHROM.POS.REF.ALT, value.var = "MAF", rm.na=T)
rownames(casted_MAF_VarBySample) <- casted_MAF_VarBySample$ID # change rownames to ID
casted_MAF_VarBySample2 <- casted_MAF_VarBySample[,-1] # remove ID column
nrow(casted_MAF_VarBySample2) # row number 
head(casted_MAF_VarBySample2)
# Out:
# [1] 97
#                             1-106934533-C-T 1-168467950-G-A 1-169329191-G-A
# 7614-L-3-Cau-DARPP32M-NeuNP 0.1242780       0.01420019      0.09107145
# 7614-L-3-Cau-DARPP32P-NeuNP 0.1516196       0.02353430      0.08362420
# 7614-L-4-GP-COUPTF2         0.1863339       0.02890274      0.07686326
# 7614-L-4-GP-DLX1            0.1209819       0.02206644      0.08452267
# 7614-L-4-GP-NeuN            0.1409085       0.01824754      0.09393965
# 7614-L-4-Put-COUPTF2        0.1664192       0.01037565      0.08310565
#                             1-180856518-T-G 1-188748555-G-A 1-212352377-G-T
# 7614-L-3-Cau-DARPP32M-NeuNP 0.00000000      0.05241424      0.007578585
# 7614-L-3-Cau-DARPP32P-NeuNP 0.03002854      0.04458780      0.000000000
# 7614-L-4-GP-COUPTF2         0.02572999      0.02608498      0.000000000
# 7614-L-4-GP-DLX1            0.01255307      0.10568621      0.010292610
# 7614-L-4-GP-NeuN            0.01710089      0.02245821      0.000000000
# ...

# %%
#remove labeling from dcasted matrix
casted_MAF_VarBySample3<-na.omit(t(casted_MAF_VarBySample2)) # Sample by variant matrix with sqrt-MAF values
var_anno<-variant_list[variant_list$variant_list %in% rownames(casted_MAF_VarBySample3),] # take variant annotation from the variants in casted_MAF_VarBySample3
casted_MAF_VarBySample3<-casted_MAF_VarBySample3[order(rownames(casted_MAF_VarBySample3)), ] # rearrange the casted_MAF_VarBySample3 matrix in order of variant name
var_anno<-var_anno[order(row.names(var_anno)), ] # rearrange the var_anno in order of variant name
casted_MAF_VarBySample3 <- cbind(casted_MAF_VarBySample3,var_anno)

# %%
label<-casted_MAF_VarBySample3[which(names(casted_MAF_VarBySample3)=='variant_list'):ncol(casted_MAF_VarBySample3)]
UMAP<-umap(casted_MAF_VarBySample3[,1:(which(names(casted_MAF_VarBySample3)=='variant_list')-1)])

# %%
UMAP<-as.data.frame(UMAP$layout)
UMAP<-cbind(UMAP,label)

# %%
names(UMAP)
# Out:
#  [1] "V1"                      "V2"
#  [3] "variant_list"            "sample_number_presented"
#  [5] "CTX"                     "CB"
#  [7] "Heart"                   "Kidney"
#  [9] "BG"                      "AMG"
# [11] "HIP"                     "THAL"
# [13] "SUB"                     "Liver"
# [15] "CLO"                     "L"
# [17] "R"                       "PF"
# [19] "F"                       "P"
# [21] "O"                       "Ins"
# [23] "Cau"                     "Put"
# [25] "GP"                      "Bulk"
# [27] "DLX1"                    "TBR1"
# [29] "COUPTF2"                 "NeuN"
# [31] "LHX2"                    "Olig2"
# [33] "PU1"                     "DARPP32M.NeuNP"
# [35] "DARPP32P.NeuNP"          "Cardiomyocyte"
# [37] "Brain_only"              "CTX_only"
# [39] "CTX_BG_only"             "BG_only"
# [41] "THAL_only"               "Left_only"
# [43] "Right_only"              "L_BR_PF_only"
# [45] "L_BR_F_only"             "L_BR_P_only"
# ...

# %%
UMAP$Brain_only<-as.character(UMAP$Brain_only)
UMAP$IN_only<-as.character(UMAP$IN_only)
UMAP$CTX_only<-as.character(UMAP$CTX_only)
UMAP$CTX_BG_only<-as.character(UMAP$CTX_BG_only)
UMAP$BG_only<-as.character(UMAP$BG_only)
UMAP$THAL_only<-as.character(UMAP$THAL_only)
UMAP$Left_only<-as.character(UMAP$Left_only)
UMAP$Right_only<-as.character(UMAP$Right_only)
UMAP$COUP_only<-as.character(UMAP$COUP_only)
UMAP$TBR_only<-as.character(UMAP$TBR_only)
UMAP$TBR_BR<-as.character(UMAP$TBR_BR)
UMAP$DLX_BR<-as.character(UMAP$DLX_BR)
UMAP$COUP_BR<-as.character(UMAP$COUP_BR)
UMAP$MSN_BR<-as.character(UMAP$MSN_BR)
UMAP$PF<-as.character(UMAP$PF)
UMAP$F<-as.character(UMAP$F)
UMAP$P<-as.character(UMAP$P)
UMAP$O<-as.character(UMAP$O)
UMAP$Ins<-as.character(UMAP$Ins)



UMAP$COUPTF2_enriched<-as.character(UMAP$COUPTF2_enriched)

# %%
options(repr.plot.width=10,repr.plot.height=10)
p1<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = CTX_only, shape = Brain_only),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"),legend.position = c(0.93, 0.2))
# # variants grouping by umap
# options(repr.plot.width=10,repr.plot.height=5)
# p2<-ggplot(df, aes(x = V1, y = V2))+ 
# geom_point(
#     aes(color = Left_only),
#     size = 3.5, 
#     alpha = 1 # It's nice to add some transparency because there may be overlap.
#   )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
# panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.8))
# # variants grouping by umap
# options(repr.plot.width=10,repr.plot.height=5)
# p3<-ggplot(df, aes(x = V1, y = V2))+ 
# geom_point(
#     aes(color = Right_only),
#     size = 3.5, 
#     alpha = 1 # It's nice to add some transparency because there may be overlap.
#   )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
# panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.7))
# # variants grouping by umap
# options(repr.plot.width=10,repr.plot.height=5)
p2<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = PF),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))
# variants grouping by umap
options(repr.plot.width=10,repr.plot.height=5)
p3<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = F),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))

p4<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = P),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))

p5<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = O),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))

p6<-ggplot(UMAP, aes(x = V1, y = V2))+ 
geom_point(
    aes(color = Ins),
    size = 3.5, 
    alpha = 1 # It's nice to add some transparency because there may be overlap.
  )+theme(panel.grid.major = element_blank(), panel.grid.minor = element_blank(),
panel.background = element_blank(), axis.line = element_line(colour = "black"), legend.position = c(0.93, 0.2))

# %%
options(repr.plot.width=30,repr.plot.height=10)
p<-p1+scale_colour_manual(values = c('green','#3283FE','#FF5005','#2BCE48','#426600') )+
p2+scale_colour_manual(values = c('green','#3283FE',"#A6D854","#FFD92F","#6699CC","#88CCEE","#B3B3B3"))+
p3+scale_colour_manual(values = c('green','#3283FE','#85660D','#782AB6','#565656','#1C8356','#16FF32','#F7E1A0','#E2E2E2','#1CBE4F','#C4451C','#DEA0FD','#FE00FA',
                                 '#325A9B','#FEAF16','#F8A19F','#90AD1C','#F6222E','#1CFFCE','#2ED9FF','#B10DA1','#C075A6') )+
p4+scale_colour_manual(values = c('green','#3283FE','#85660D','#782AB6','#565656','#1C8356','#16FF32','#F7E1A0','#E2E2E2','#1CBE4F','#C4451C','#DEA0FD','#FE00FA',
                                  '#325A9B','#FEAF16','#F8A19F','#90AD1C','#F6222E','#1CFFCE','#2ED9FF','#B10DA1','#C075A6') )+
p5+scale_colour_manual(values = c('green','#3283FE','#85660D','#782AB6','#565656','#1C8356','#16FF32','#F7E1A0','#E2E2E2','#1CBE4F','#C4451C','#DEA0FD','#FE00FA',
                                 '#325A9B','#FEAF16','#F8A19F','#90AD1C','#F6222E','#1CFFCE','#2ED9FF','#B10DA1','#C075A6') )+
p6+scale_colour_manual(values = c('green','#3283FE','#85660D','#782AB6','#565656','#1C8356','#16FF32','#F7E1A0','#E2E2E2','#1CBE4F','#C4451C','#DEA0FD','#FE00FA',
                                 '#325A9B','#FEAF16','#F8A19F','#90AD1C','#F6222E','#1CFFCE','#2ED9FF','#B10DA1','#C075A6') )
p
# Out:
# plot without title

# %%
df1<-casted_MAF_VarBySample3[,1:(which(names(casted_MAF_VarBySample3)=='variant_list')-1)]
print(paste("nrows before filtering :",nrow(df1)))
# Remove variants with zero values in all samples
all_zero_row_in_df1<-df1[rowSums(df1 != 0) == 0, ]
label<-label[!label$variant_list %in% rownames(all_zero_row_in_df1),]
df1<-df1[rowSums(df1 != 0) > 0, ]
df1_cor<-cor(t(df1),method = "pearson")
print(paste("removed rows due to zero values in all column :",nrow(all_zero_row_in_df1)))
print(paste("remaining rows :",nrow(df1)))
# Out:
# [1] "nrows before filtering : 283"
# [1] "removed rows due to zero values in all column : 1"
# [1] "remaining rows : 282"

# %%
myCol<-as.data.frame(label[,])
myCol$Brain_only_col[myCol$Brain_only %in% c("1")]<-"Black"
myCol$COUPTF2_enriched_col[myCol$COUPTF2_enriched %in% c("1")]<-"Blue"
 myCol$Hemisphere_col[myCol$Left_only %in% c("1")]<-"Green"
 myCol$Hemisphere_col[myCol$Right_only %in% c("1")]<-"red"
# myCol$Brain_only_col[myCol$Brain_only %in% c("1")]<-"#76FFF7"
myCol$IN_only_col[myCol$IN_only %in% c("1")]<-"Purple"
myCol$COUP_only_col[myCol$COUP_only %in% c("1")]<-"Yellow"
myCol$TBR_only_col[myCol$TBR_only %in% c("1")]<-"pink"

myCol$DLX_BR_col[myCol$DLX_BR %in% c("1")]<-"grey"
myCol$TBR_BR_col[myCol$TBR_BR %in% c("1")]<-"grey90"
myCol$COUP_BR_col[myCol$COUP_BR %in% c("1")]<-"cyan"

myCol$PF_col[(myCol$PF %in% c("1") & myCol$Bulk %in% c("1") & myCol$L %in% c("1"))]<-"magenta"
myCol$F_col[(myCol$F %in% c("1") & myCol$Bulk %in% c("1") & myCol$L %in% c("1"))]<-"magenta"
myCol$P_col[(myCol$P %in% c("1") & myCol$Bulk %in% c("1") & myCol$L %in% c("1"))]<-"magenta"
myCol$O_col[(myCol$O %in% c("1") & myCol$Bulk %in% c("1") & myCol$L %in% c("1"))]<-"magenta"
myCol$Ins_col[(myCol$Ins %in% c("1") & myCol$Bulk %in% c("1") & myCol$L %in% c("1"))]<-"magenta"



myCol2<-as.matrix(cbind(myCol$Brain_only_col, myCol$Hemisphere_col, myCol$COUPTF2_enriched_col, myCol$IN_only_col, myCol$COUP_only_col,
                        myCol$TBR_only_col, myCol$DLX_BR_col, myCol$TBR_BR_col,myCol$COUP_BR_col,myCol$PF_col,myCol$F_col,myCol$P_col,myCol$O_col,myCol$Ins_col))
colnames(myCol2)<-c("Brain_only_col","Hemisphere_col","COUPTF2_enriched_col","IN_only_col","COUP_only_col","TBR_only_col","DLX_BR_col","TBR_BR_col","COUP_BR_col",
                   "PF_col","F_col","P_col","O_col","Ins_col")

# %%
Colors = c("yellow","red")
Colors = colorRampPalette(Colors)(100)

options(repr.plot.width=20, repr.plot.height=20)

heatmap.plus(df1_cor,
             distfun = function(x) dist(x,method = 'manhattan'),
             col=Colors, 
             RowSideColors=myCol2,
             margins=c(7,7),
             scale = c("none"))
# Out:
# plot without title

# %%
Colors = c("yellow","red")
Colors = colorRampPalette(Colors)(100)

options(repr.plot.width=20, repr.plot.height=10)

heatmap.plus(df1_cor,
             distfun = function(x) dist(x,method = 'euclidean'),
             col=Colors, 
             RowSideColors=myCol2,
             margins=c(7,7),
             scale = c("none"))
# Out:
# plot without title

# %%
options(repr.plot.width=12, repr.plot.height=12)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$THAL_only)
options(repr.plot.width=12, repr.plot.height=12)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$TBR_BR)
options(repr.plot.width=12, repr.plot.height=12)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$DLX_BR)
options(repr.plot.width=12, repr.plot.height=12)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$Right_only)
options(repr.plot.width=12, repr.plot.height=12)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$Left_only)
options(repr.plot.width=12, repr.plot.height=12)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$CTX_only)
options(repr.plot.width=12, repr.plot.height=12)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$BG_only)
# Out:
# Error in df$THAL_only: object of type 'closure' is not subsettable
# Traceback:

# %%
pdf(file="7669_VarByVar_corr_label_DLX1only.pdf",height=30,width=30)
Colors = c("blue4","white","red4")
Colors=colorRampPalette(Colors)(100)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$IN_only)
dev.off()
pdf(file="7669_VarByVar_corr_label_Rightonly.pdf",height=30,width=30)
Colors = c("blue4","white","red4")
Colors=colorRampPalette(Colors)(100)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$Right_only)
dev.off()
pdf(file="7669_VarByVar_corr_label_Leftonly.pdf",height=30,width=30)
Colors = c("blue4","white","red4")
Colors=colorRampPalette(Colors)(100)
heatmap.2(na.omit(df1_cor),trace="none",col="bluered",margins=c(8,8),RowSideColors=df$Left_only)
dev.off()
